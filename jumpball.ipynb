# %% [markdown]
# # **Does Winning The Jump Ball Matter?**

# %% [markdown]
# ### **First lets get the NBA season (2021-22) data**

# %%
import requests
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
url = 'https://stats.nba.com/stats/leaguegamelog'
headers= {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36', 'Referer': 'https://www.nba.com/'}
payload = {
    'Counter': '1000',
    'DateFrom': '',
    'DateTo': '',
    'Direction': 'DESC',
    'LeagueID': '00',
    'PlayerOrTeam': 'T',
    'Season': '2021-22',
    'SeasonType': 'Regular Season',
    'Sorter': 'DATE'}

jsonData = requests.get(url, headers=headers, params=payload).json()


rows = jsonData['resultSets'][0]['rowSet']
columns = jsonData['resultSets'][0]['headers']

df = pd.DataFrame(rows, columns=columns)

# %%
df.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME     GAME_ID  \
# 0     22021  1610612741               CHI           Chicago Bulls  0022101224
# 1     22021  1610612750               MIN  Minnesota Timberwolves  0022101224
# 2     22021  1610612755               PHI      Philadelphia 76ers  0022101228
# 3     22021  1610612765               DET         Detroit Pistons  0022101228
# 4     22021  1610612738               BOS          Boston Celtics  0022101223
#
#     GAME_DATE      MATCHUP WL  MIN  FGM  ...  DREB  REB  AST  STL  BLK  TOV  \
# 0  2022-04-10    CHI @ MIN  W  240   44  ...    32   48   22    9    3   23
# 1  2022-04-10  MIN vs. CHI  L  240   46  ...    23   32   30    7    9   13
# 2  2022-04-10  PHI vs. DET  W  240   46  ...    32   42   25   13    6   11
# 3  2022-04-10    DET @ PHI  L  240   38  ...    27   42   26    4    4   20
# 4  2022-04-10    BOS @ MEM  W  240   54  ...    42   56   34    5    2   15
#
#    PF  PTS  PLUS_MINUS  VIDEO_AVAILABLE
# 0  22  124           4                1
# 1  23  120          -4                1
# 2  23  118          12                1
# 3  16  106         -12                1
# 4  20  139          29                1
#
# [5 rows x 29 columns]

# %% [markdown]
# ### **Now we will get the play by play data so we can obtain the jumpball winner**

# %%
def game_plays(gameId):
    url = f'https://cdn.nba.com/static/json/liveData/playbyplay/playbyplay_{gameId}.json'
    jsonData = requests.get(url).json()
    play_by_play = pd.json_normalize(jsonData, record_path=['game', 'actions'])
    
    return play_by_play

dt = game_plays('0022101224')

# %%
dt.head()
# Out:
#    actionNumber        clock              timeActual  period periodType  \
# 0             2  PT12M00.00S  2022-04-11T00:40:51.3Z       1    REGULAR
# 1             4  PT11M57.00S  2022-04-11T00:40:54.0Z       1    REGULAR
# 2             7  PT11M46.00S  2022-04-11T00:41:05.1Z       1    REGULAR
# 3             8  PT11M42.00S  2022-04-11T00:41:09.1Z       1    REGULAR
# 4             9  PT11M28.00S  2022-04-11T00:41:22.3Z       1    REGULAR
#
#   actionType    subType          qualifiers  personId          x  ...  \
# 0     period      start                  []         0        NaN  ...
# 1   jumpball  recovered                  []   1627736        NaN  ...
# 2        3pt  Jump Shot                  []   1630162  68.281866  ...
# 3    rebound  defensive                  []   1630245        NaN  ...
# 4        2pt       Hook  [pointsinthepaint]    202684  10.726018  ...
#
#    stealPlayerName  stealPersonId officialId foulPersonalTotal  \
# 0              NaN            NaN        NaN               NaN
# 1              NaN            NaN        NaN               NaN
# 2              NaN            NaN        NaN               NaN
# 3              NaN            NaN        NaN               NaN
# 4              NaN            NaN        NaN               NaN
#
#   foulTechnicalTotal  foulDrawnPlayerName  foulDrawnPersonId  blockPlayerName  \
# 0                NaN                  NaN                NaN              NaN
# 1                NaN                  NaN                NaN              NaN
# 2                NaN                  NaN                NaN              NaN
# 3                NaN                  NaN                NaN              NaN
# 4                NaN                  NaN                NaN              NaN
#
#    blockPersonId value
# 0            NaN   NaN
# 1            NaN   NaN
# 2            NaN   NaN
# 3            NaN   NaN
# 4            NaN   NaN
#
# [5 rows x 54 columns]

# %% [markdown]
# ### **We will get the play by plays for the 2021-2022 season games**

# %%
plays = []

for i in list(set(df['GAME_ID'].tolist())):
    pl = game_plays(i)
    pl['GAME_ID'] = i
    plays.append(pl)

# %%
possession = []

for t in plays:
    t = t.loc[t['possession'] != 0].reset_index(drop = False)
    t  = t[t.index.isin([0])]
    possession.append(t)

# %%
jump_ball_possession = pd.concat(possession)  
    
jump_ball_dic = dict(zip(jump_ball_possession.GAME_ID, jump_ball_possession.possession))
df['jump_ball_winner'] = df['GAME_ID'].map(jump_ball_dic).astype(int)

# %% [markdown]
# ### **We can now see which team won the jumpball**

# %%
df.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME     GAME_ID  \
# 0     22021  1610612741               CHI           Chicago Bulls  0022101224
# 1     22021  1610612750               MIN  Minnesota Timberwolves  0022101224
# 2     22021  1610612755               PHI      Philadelphia 76ers  0022101228
# 3     22021  1610612765               DET         Detroit Pistons  0022101228
# 4     22021  1610612738               BOS          Boston Celtics  0022101223
#
#     GAME_DATE      MATCHUP WL  MIN  FGM  ...  REB  AST  STL  BLK  TOV  PF  \
# 0  2022-04-10    CHI @ MIN  W  240   44  ...   48   22    9    3   23  22
# 1  2022-04-10  MIN vs. CHI  L  240   46  ...   32   30    7    9   13  23
# 2  2022-04-10  PHI vs. DET  W  240   46  ...   42   25   13    6   11  23
# 3  2022-04-10    DET @ PHI  L  240   38  ...   42   26    4    4   20  16
# 4  2022-04-10    BOS @ MEM  W  240   54  ...   56   34    5    2   15  20
#
#    PTS  PLUS_MINUS  VIDEO_AVAILABLE  jump_ball_winner
# 0  124           4                1        1610612750
# 1  120          -4                1        1610612750
# 2  118          12                1        1610612755
# 3  106         -12                1        1610612755
# 4  139          29                1        1610612738
#
# [5 rows x 30 columns]

# %% [markdown]
# ### **Categorize team winner as 1 and 0 for otherwise**

# %%
df['Home'] = np.where(df['MATCHUP'].str.contains("vs.") == True, 1, 0)
df['Won_Jumpball'] = np.where(df['jump_ball_winner'] == df['TEAM_ID'], 1, 0)
df['Won'] = np.where(df['WL'] == 'W', 1, 0)

df.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME     GAME_ID  \
# 0     22021  1610612741               CHI           Chicago Bulls  0022101224
# 1     22021  1610612750               MIN  Minnesota Timberwolves  0022101224
# 2     22021  1610612755               PHI      Philadelphia 76ers  0022101228
# 3     22021  1610612765               DET         Detroit Pistons  0022101228
# 4     22021  1610612738               BOS          Boston Celtics  0022101223
#
#     GAME_DATE      MATCHUP WL  MIN  FGM  ...  BLK  TOV  PF  PTS  PLUS_MINUS  \
# 0  2022-04-10    CHI @ MIN  W  240   44  ...    3   23  22  124           4
# 1  2022-04-10  MIN vs. CHI  L  240   46  ...    9   13  23  120          -4
# 2  2022-04-10  PHI vs. DET  W  240   46  ...    6   11  23  118          12
# 3  2022-04-10    DET @ PHI  L  240   38  ...    4   20  16  106         -12
# 4  2022-04-10    BOS @ MEM  W  240   54  ...    2   15  20  139          29
#
#    VIDEO_AVAILABLE  jump_ball_winner  Home  Won_Jumpball  Won
# 0                1        1610612750     0             0    1
# 1                1        1610612750     1             1    0
# 2                1        1610612755     1             1    1
# 3                1        1610612755     0             0    0
# 4                1        1610612738     0             1    1
#
# [5 rows x 33 columns]

# %% [markdown]
# ### **Logistic Regression**

# %%
import statsmodels.api as sm

x = df[['Won_Jumpball']]
y = df['Won']

x = sm.add_constant(x)

model = sm.Logit(y, x).fit()
predictions = model.predict(x) 

print_model = model.summary()
print(print_model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.692386
#          Iterations 3
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    Won   No. Observations:                 2460
# Model:                          Logit   Df Residuals:                     2458
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 11 Sep 2022   Pseudo R-squ.:                0.001099
# Time:                        11:48:53   Log-Likelihood:                -1703.3
# converged:                       True   LL-Null:                       -1705.1
# Covariance Type:            nonrobust   LLR p-value:                   0.05289
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           -0.0781      0.057     -1.368      0.171      -0.190       0.034
# Won_Jumpball     0.1562      0.081      1.935      0.053      -0.002       0.314
# ================================================================================

# %% [markdown]
# ### **Accuracy**

# %%
from sklearn.metrics import accuracy_score
x['pred_label'] = (predictions>0.5).astype(int)
x['Won'] = y

accuracy_score(x['Won'],x['pred_label'])
# Out:
# 0.5195121951219512

# %% [markdown]
# ### **Home Court advantage**

# %%
home_games = df.loc[df['Home'] == 1]

x = home_games[['Won_Jumpball']]
y = home_games['Won']

x = sm.add_constant(x)

model = sm.Logit(y, x).fit()
predictions = model.predict(x) 

x['pred_label'] = (predictions>0.5).astype(int)
x['Won'] = y

accuracy_score(x['Won'],x['pred_label'])
# Out:
# Optimization terminated successfully.
#          Current function value: 0.688591
#          Iterations 4
# 0.5439024390243903

# %% [markdown]
# ## **Overtime**

# %%
overtime_games = df.loc[df['MIN'] > 240]
overtime_game_ids = list(set(overtime_games['GAME_ID'].tolist()))
play_by_play_data = pd.concat(plays)
overtime_plays = play_by_play_data[play_by_play_data['GAME_ID'].isin(overtime_game_ids)]
overtime_plays = overtime_plays.groupby('GAME_ID')
overtime_plays=[group for _, group in overtime_plays]

# %%
overtime = []

for i in overtime_plays:
   
    o = i.loc[i['periodType'] == 'OVERTIME'].reset_index(drop = False)
    o = o.loc[o['actionType'] == 'jumpball'].head(1)
    
    if len(o) == 0:
        o2 = i.loc[i['periodType'] == 'OVERTIME'].reset_index(drop = False)
        o3 = o2.loc[o2['subType'] == 'jumpball'].reset_index(drop = True)
        
        if len(o3) !=0:
            o = o2.loc[o2['index'] == o3['index'][0]+1]
    
    if len(o) == 0:
        o = o2.loc[o2['possession'] > 0]
        o = o.head(1)
        
    overtime.append(o)

# %%
jump_ball_possession_overtime = pd.concat(overtime)

# %%
overtime_jump_ball_dic = dict(zip(jump_ball_possession_overtime.GAME_ID, jump_ball_possession_overtime.possession))
overtime_games['jump_ball_winner'] = overtime_games['GAME_ID'].map(overtime_jump_ball_dic)
overtime_games['jump_ball_winner'] = overtime_games['jump_ball_winner'].astype(int)
overtime_games['Won_Jumpball'] = np.where(overtime_games['jump_ball_winner'] == overtime_games['TEAM_ID'], 1, 0)

# %% [markdown]
# ### **Logistic Regression**

# %%
x = overtime_games[['Won_Jumpball']]
y = overtime_games['Won']

x = sm.add_constant(x)

model = sm.Logit(y, x).fit()
predictions = model.predict(x) 

print_model = model.summary()
print(print_model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.687787
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    Won   No. Observations:                  116
# Model:                          Logit   Df Residuals:                      114
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 11 Sep 2022   Pseudo R-squ.:                0.007733
# Time:                        11:49:22   Log-Likelihood:                -79.783
# converged:                       True   LL-Null:                       -80.405
# Covariance Type:            nonrobust   LLR p-value:                    0.2648
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.2076      0.264      0.786      0.432      -0.310       0.725
# Won_Jumpball    -0.4153      0.373     -1.112      0.266      -1.147       0.317
# ================================================================================

# %% [markdown]
# ### **Accuracy**

# %%
x['pred_label'] = (predictions>0.5).astype(int)
x['Won'] = y

accuracy_score(x['Won'],x['pred_label'])
# Out:
# 0.5517241379310345

# %% [markdown]
# ### **Logistic Regression**

# %%
home_games = overtime_games.loc[overtime_games['Home'] == 1]
x = home_games[['Won_Jumpball']]
y = home_games['Won']

x = sm.add_constant(x)

model = sm.Logit(y, x).fit()
predictions = model.predict(x) 

print_model = model.summary()
print(print_model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.687054
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    Won   No. Observations:                   58
# Model:                          Logit   Df Residuals:                       56
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 11 Sep 2022   Pseudo R-squ.:                0.007940
# Time:                        11:49:36   Log-Likelihood:                -39.849
# converged:                       True   LL-Null:                       -40.168
# Covariance Type:            nonrobust   LLR p-value:                    0.4245
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.1335      0.366      0.365      0.715      -0.584       0.851
# Won_Jumpball    -0.4212      0.529     -0.796      0.426      -1.458       0.615
# ================================================================================

# %% [markdown]
# ### **Accuracy**

# %%
x['pred_label'] = (predictions>0.5).astype(int)
x['Won'] = y

accuracy_score(x['Won'],x['pred_label'])
# Out:
# 0.5517241379310345
